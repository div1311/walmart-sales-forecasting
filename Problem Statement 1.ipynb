# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Walmart (1).csv",parse_dates=['Date'], dayfirst=True)

# %%
data
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %% [markdown]
# ## Data Exploration:
# ### Store 10
# ### Store 22
# ### Store 34
# ### Store 17
# ### Store 14

# %%
df10=data[data["Store"]==10]
df22=data[data["Store"]==22]
df34=data[data["Store"]==34]
df17=data[data["Store"]==17]
df14=data[data["Store"]==14]

# %%
df10=df10.drop(["Store"],axis=1)
df10=df10.set_index("Date")

df22=df22.drop(["Store"],axis=1)
df22=df22.set_index("Date")

df34=df34.drop(["Store"],axis=1)
df34=df34.set_index("Date")

df17=df17.drop(["Store"],axis=1)
df17=df17.set_index("Date")

df14=df14.drop(["Store"],axis=1)
df14=df14.set_index("Date")

# %%
df10
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    2193048.75             0        54.34       2.962  126.442065
# 2010-02-12    2176028.52             1        49.96       2.828  126.496258
# 2010-02-19    2113432.58             0        58.22       2.915  126.526286
# 2010-02-26    2006774.96             0        52.77       2.825  126.552286
# 2010-03-05    1987090.09             0        55.92       2.877  126.578286
# ...                  ...           ...          ...         ...         ...
# 2012-09-28    1694862.41             0        82.52       3.966  131.043000
# 2012-10-05    1758971.38             0        80.88       4.132  131.075667
# 2012-10-12    1713889.11             0        76.03       4.468  131.108333
# 2012-10-19    1734834.82             0        72.71       4.449  131.149968
# 2012-10-26    1744349.05             0        70.50       4.301  131.193097
#
#             Unemployment
# Date
# ...

# %%
df22
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    1033017.37             0        24.36       2.788  135.352461
# 2010-02-12    1022571.25             1        28.14       2.771  135.411308
# 2010-02-19     988467.61             0        31.96       2.747  135.465778
# 2010-02-26     899761.48             0        35.98       2.753  135.519519
# 2010-03-05    1009201.24             0        36.82       2.766  135.573260
# ...                  ...           ...          ...         ...         ...
# 2012-09-28     976479.51             0        62.17       4.018  142.765750
# 2012-10-05    1009887.36             0        62.09       4.027  142.851683
# 2012-10-12    1004039.84             0        54.18       4.029  142.937617
# 2012-10-19     978027.95             0        55.28       4.000  142.863363
# 2012-10-26    1094422.69             0        57.58       3.917  142.762411
#
#             Unemployment
# Date
# ...

# %%
df34
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05     956228.96             0        35.44       2.598  126.442065
# 2010-02-12     994610.99             1        36.13       2.573  126.496258
# 2010-02-19     983963.07             0        38.36       2.540  126.526286
# 2010-02-26     905756.13             0        37.28       2.590  126.552286
# 2010-03-05     918295.79             0        42.65       2.654  126.578286
# ...                  ...           ...          ...         ...         ...
# 2012-09-28     928629.31             0        67.06       3.666  131.043000
# 2012-10-05     968896.68             0        65.41       3.620  131.075667
# 2012-10-12     948613.39             0        59.94       3.603  131.108333
# 2012-10-19     963516.28             0        58.47       3.610  131.149968
# 2012-10-26     956987.81             0        57.95       3.514  131.193097
#
#             Unemployment
# Date
# ...

# %%
df17
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05     789036.02             0        23.11       2.666  126.442065
# 2010-02-12     841951.91             1        18.36       2.671  126.496258
# 2010-02-19     800714.00             0        25.06       2.654  126.526286
# 2010-02-26     749549.55             0        15.64       2.667  126.552286
# 2010-03-05     783300.05             0        31.58       2.681  126.578286
# ...                  ...           ...          ...         ...         ...
# 2012-09-28     972716.24             0        57.77       3.821  131.043000
# 2012-10-05     952609.17             0        52.81       3.815  131.075667
# 2012-10-12     919878.34             0        44.82       3.797  131.108333
# 2012-10-19     957356.84             0        48.16       3.781  131.149968
# 2012-10-26     943465.29             0        39.94       3.755  131.193097
#
#             Unemployment
# Date
# ...

# %%
df14
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    2623469.95             0        27.31       2.784  181.871190
# 2010-02-12    1704218.84             1        27.73       2.773  181.982317
# 2010-02-19    2204556.70             0        31.27       2.745  182.034782
# 2010-02-26    2095591.63             0        34.89       2.754  182.077469
# 2010-03-05    2237544.75             0        37.13       2.777  182.120157
# ...                  ...           ...          ...         ...         ...
# 2012-09-28    1522512.20             0        64.88       3.997  192.013558
# 2012-10-05    1687592.16             0        64.89       3.985  192.170412
# 2012-10-12    1639585.61             0        54.47       4.000  192.327265
# 2012-10-19    1590274.72             0        56.47       3.969  192.330854
# 2012-10-26    1704357.62             0        58.85       3.882  192.308899
#
#             Unemployment
# Date
# ...

# %%
print("Missing Values in data\n")
print(data.isna().sum())
# Out:
# Missing Values in data
#
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
print("Duplicate Values in data: ",data.duplicated().sum())
# Out:
# Duplicate Values in data:  0

# %% [markdown]
# # Store 10

# %%
df10.head()
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    2193048.75             0        54.34       2.962  126.442065
# 2010-02-12    2176028.52             1        49.96       2.828  126.496258
# 2010-02-19    2113432.58             0        58.22       2.915  126.526286
# 2010-02-26    2006774.96             0        52.77       2.825  126.552286
# 2010-03-05    1987090.09             0        55.92       2.877  126.578286
#
#             Unemployment
# Date
# 2010-02-05         9.765
# 2010-02-12         9.765
# 2010-02-19         9.765
# 2010-02-26         9.765
# 2010-03-05         9.765

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2010-02-05 to 2012-10-26
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly_Sales  143 non-null    float64
#  1   Holiday_Flag  143 non-null    int64
#  2   Temperature   143 non-null    float64
#  3   Fuel_Price    143 non-null    float64
#  4   CPI           143 non-null    float64
#  5   Unemployment  143 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
df10.describe()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean   1.899425e+06      0.069930    72.241189    3.575923  128.679669
# std    3.022621e+05      0.255926    14.031578    0.446957    1.858300
# min    1.627707e+06      0.000000    42.580000    2.825000  126.064000
# 25%    1.740771e+06      0.000000    59.060000    3.107000  126.590094
# 50%    1.827522e+06      0.000000    73.560000    3.675000  129.075677
# 75%    1.944111e+06      0.000000    85.110000    3.905000  130.502414
# max    3.749058e+06      1.000000    95.360000    4.468000  131.193097
#
#        Unemployment
# count    143.000000
# mean       8.362965
# std        0.843684
# min        6.943000
# 25%        7.545000
# 50%        8.494000
# 75%        9.003000
# max        9.765000

# %%
# Line Plot of Weekly Sales over Time
plt.figure(figsize=(12, 6))
plt.plot(df10.index, df10['Weekly_Sales'],marker='o', linestyle='-')
plt.title('Weekly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Histogram of Weekly Sales
plt.figure(figsize=(8, 5))
sns.histplot(df10['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df10.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
average_sales_by_holiday = df10.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()

# Create a bar plot to compare average sales for holiday and non-holiday weeks
plt.figure(figsize=(8, 5))
sns.barplot(data=average_sales_by_holiday, x='Holiday_Flag', y='Weekly_Sales')
plt.title('Impact of Holidays on Weekly Sales')
plt.xlabel('Holiday Flag')
plt.ylabel('Average Weekly Sales')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.show()

# %%
# Enhanced scatter plot of Fuel Prices vs. CPI
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='CPI', y='Fuel_Price')
plt.title('Fuel_Prices vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Fuel_Prices')
plt.show()

# %%
# Enhanced scatter plot of Unemployment vs. CPI
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='Unemployment', y='CPI')
plt.title('Unemployment vs. CPI')
plt.xlabel('Unemployment')
plt.ylabel('CPI')
plt.show()

# %%
# Enhanced scatter plot of Temperature vs. Weekly Sales
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='Temperature', y='Weekly_Sales')
plt.title('Weekly Sales vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Enhanced scatter plot of Fuel Price vs. Weekly Sales
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='Fuel_Price', y='Weekly_Sales')
plt.title('Weekly Sales vs. Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Enhanced scatter plot of CPI vs. Weekly Sales
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='CPI', y='Weekly_Sales')
plt.title('Weekly Sales vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Enhanced scatter plot of Unemployment vs. Weekly Sales
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df10, x='Unemployment', y='Weekly_Sales')
plt.title('Weekly Sales vs. Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")


df10['Year'] = df10.index.year

# Create a line plot for each year
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Group the data by year and plot each year's weekly sales on the same graph
for year in df10['Year'].unique():
    year_data = df10[df10['Year'] == year]
    sns.lineplot(data=year_data, x=year_data.index, y='Weekly_Sales', label=year)

plt.title('Year-Wise Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend(title='Year')
plt.show()

# Don't forget to remove the 'Year' column if it's not needed for further analysis
df10.drop('Year', axis=1, inplace=True)

# %% [markdown]
# # Check for stationarity by Dickey-Fuller test

# %%
from statsmodels.tsa.stattools import adfuller

# Define a function to perform the Dickey-Fuller test and display the results
def test_stationarity(timeseries):
    result = adfuller(timeseries, autolag='AIC')
    print("Dickey-Fuller Test Results:")
    print(f'Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags Used: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print(f'Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    
    # Determine if the series is stationary based on the p-value
    if result[1] <= 0.05:
        print("\nResult: The time series is stationary.")
    else:
        print("\nResult: The time series is not stationary.")

test_stationarity(df10['Weekly_Sales'])
# Out:
# Dickey-Fuller Test Results:
# Test Statistic: -5.200703175699106
# p-value: 8.763067535583776e-06
# Number of Lags Used: 4
# Number of Observations Used: 138
# Critical Values:
#    1%: -3.47864788917503
#    5%: -2.882721765644168
#    10%: -2.578065326612056
#
# Result: The time series is stationary.

# %% [markdown]
# # Decomposing

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.figure(figsize=(20, 8))
plt.plot(df10["Weekly_Sales"], label='Original Data', marker='o', linestyle='-')

# %%
decompose_result=seasonal_decompose(df10["Weekly_Sales"])
decompose_result.plot();

# %% [markdown]
# # Auto ARIMA

# %%
from pmdarima import auto_arima
order=auto_arima(df10["Weekly_Sales"])

# %%
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  143
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -1987.255
# Date:                Wed, 08 Nov 2023   AIC                           3982.510
# Time:                        01:56:18   BIC                           3994.361
# Sample:                    02-05-2010   HQIC                          3987.326
#                          - 10-26-2012
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   8.683e+05    1.3e+05      6.693      0.000    6.14e+05    1.12e+06
# ar.L1          0.4181      0.043      9.820      0.000       0.335       0.502
# ar.L2          0.1251      0.069      1.821      0.069      -0.010       0.260
# ...

# %% [markdown]
# # Model Building

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX,SARIMAXResults

# %% [markdown]
# ## ARIMA Model

# %%
ar_model=ARIMA(df10["Weekly_Sales"],order=(2,0,0),seasonal_order=(2,0,0,53),enforce_invertibility=False,
               enforce_stationarity=False)
ar_model=ar_model.fit()

# %%
forecast1=ar_model.forecast(steps=12)

# %%
forecast1
# Out:
# 2012-11-02    1.791986e+06
# 2012-11-09    1.869988e+06
# 2012-11-16    1.974881e+06
# 2012-11-23    1.883301e+06
# 2012-11-30    2.431540e+06
# 2012-12-07    2.159614e+06
# 2012-12-14    2.223110e+06
# 2012-12-21    2.312969e+06
# 2012-12-28    2.845729e+06
# 2013-01-04    2.228111e+06
# 2013-01-11    1.759216e+06
# 2013-01-18    1.774441e+06
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df10["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast1, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# ## SARIMAX Model

# %%
model=SARIMAX(df10["Weekly_Sales"],order=(2,0,0),seasonal_order=(2,0,0,53),enforce_invertibility=False,
              enforce_stationarity=False)
model=model.fit()

# %%
forecast2=model.forecast(steps=12)

# %%
forecast2
# Out:
# 2012-11-02    1.751507e+06
# 2012-11-09    1.824406e+06
# 2012-11-16    1.963767e+06
# 2012-11-23    1.863337e+06
# 2012-11-30    2.539575e+06
# 2012-12-07    2.386421e+06
# 2012-12-14    2.340074e+06
# 2012-12-21    2.478148e+06
# 2012-12-28    3.197820e+06
# 2013-01-04    2.614762e+06
# 2013-01-11    1.678309e+06
# 2013-01-18    1.698084e+06
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df10["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast2, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # Store 22

# %%
df = df22

# %%
df.head()
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    1033017.37             0        24.36       2.788  135.352461
# 2010-02-12    1022571.25             1        28.14       2.771  135.411308
# 2010-02-19     988467.61             0        31.96       2.747  135.465778
# 2010-02-26     899761.48             0        35.98       2.753  135.519519
# 2010-03-05    1009201.24             0        36.82       2.766  135.573260
#
#             Unemployment
# Date
# 2010-02-05         8.283
# 2010-02-12         8.283
# 2010-02-19         8.283
# 2010-02-26         8.283
# 2010-03-05         8.283

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2010-02-05 to 2012-10-26
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly_Sales  143 non-null    float64
#  1   Holiday_Flag  143 non-null    int64
#  2   Temperature   143 non-null    float64
#  3   Fuel_Price    143 non-null    float64
#  4   CPI           143 non-null    float64
#  5   Unemployment  143 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean   1.028501e+06      0.069930    54.897133    3.441741  139.011284
# std    1.612514e+05      0.255926    15.664751    0.455203    2.439042
# min    7.742623e+05      0.000000    20.610000    2.716000  135.352461
# 25%    9.614760e+05      0.000000    43.095000    2.938000  136.624470
# 50%    9.966288e+05      0.000000    56.440000    3.577000  139.002833
# 75%    1.052934e+06      0.000000    69.400000    3.845000  141.257411
# max    1.962445e+06      1.000000    79.220000    4.101000  142.937617
#
#        Unemployment
# count    143.000000
# mean       8.069371
# std        0.368337
# min        7.503000
# 25%        7.706000
# 50%        8.252000
# 75%        8.433000
# max        8.572000

# %%
# Line Plot of Weekly Sales over Time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Weekly_Sales'], marker='o', linestyle='-')
plt.title('Weekly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Histogram of Weekly Sales
plt.figure(figsize=(8, 5))
sns.histplot(df['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
average_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()

# Create a bar plot to compare average sales for holiday and non-holiday weeks
plt.figure(figsize=(8, 5))
sns.barplot(data=average_sales_by_holiday, x='Holiday_Flag', y='Weekly_Sales')
plt.title('Impact of Holidays on Weekly Sales')
plt.xlabel('Holiday Flag')
plt.ylabel('Average Weekly Sales')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.show()

# %%
# Create subplots for enhanced scatter plots
plt.figure(figsize=(16, 12))

# Enhanced scatter plot of Fuel Prices vs. CPI
plt.subplot(2, 3, 1)
sns.scatterplot(data=df10, x='CPI', y='Fuel_Price')
plt.title('Fuel_Prices vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Fuel_Prices')

# Enhanced scatter plot of Unemployment vs. CPI
plt.subplot(2, 3, 2)
sns.scatterplot(data=df, x='Unemployment', y='CPI')
plt.title('Unemployment vs. CPI')
plt.xlabel('Unemployment')
plt.ylabel('CPI')

# Enhanced scatter plot of Temperature vs. Weekly Sales
plt.subplot(2, 3, 3)
sns.scatterplot(data=df, x='Temperature', y='Weekly_Sales')
plt.title('Weekly Sales vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Fuel Price vs. Weekly Sales
plt.subplot(2, 3, 4)
sns.scatterplot(data=df, x='Fuel_Price', y='Weekly_Sales')
plt.title('Weekly Sales vs. Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of CPI vs. Weekly Sales
plt.subplot(2, 3, 5)
sns.scatterplot(data=df, x='CPI', y='Weekly_Sales')
plt.title('Weekly Sales vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Unemployment vs. Weekly Sales
plt.subplot(2, 3, 6)
sns.scatterplot(data=df, x='Unemployment', y='Weekly_Sales')
plt.title('Weekly Sales vs. Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')

plt.tight_layout()
plt.show()

# %%
# Year-wise analysis
df['Year'] = df.index.year

# Create a line plot for each year
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Group the data by year and plot each year's weekly sales on the same graph
for year in df['Year'].unique():
    year_data = df[df['Year'] == year]
    sns.lineplot(data=year_data, x=year_data.index, y='Weekly_Sales', label=year)

plt.title('Year-Wise Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend(title='Year')
plt.show()

# Don't forget to remove the 'Year' column if it's not needed for further analysis
df.drop('Year', axis=1, inplace=True)

# %% [markdown]
# ## Check stationarity

# %%
# Define a function to perform the Dickey-Fuller test and display the results
def test_stationarity(timeseries):
    result = adfuller(timeseries, autolag='AIC')
    print("Dickey-Fuller Test Results:")
    print(f'Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags Used: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print(f'Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    
    # Determine if the series is stationary based on the p-value
    if result[1] <= 0.05:
        print("\nResult: The time series is stationary.")
    else:
        print("\nResult: The time series is not stationary.")

test_stationarity(df22['Weekly_Sales'])
# Out:
# Dickey-Fuller Test Results:
# Test Statistic: -6.13813900845378
# p-value: 8.092841588352181e-08
# Number of Lags Used: 4
# Number of Observations Used: 138
# Critical Values:
#    1%: -3.47864788917503
#    5%: -2.882721765644168
#    10%: -2.578065326612056
#
# Result: The time series is stationary.

# %%
plt.figure(figsize=(20, 8))
plt.plot(df22["Weekly_Sales"], label='Original Data', marker='o', linestyle='-')

# %%
decompose_result=seasonal_decompose(df22["Weekly_Sales"])
decompose_result.plot();

# %% [markdown]
# ## Auto ARIMA

# %%
order=auto_arima(df22["Weekly_Sales"])
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  143
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -1902.336
# Date:                Wed, 08 Nov 2023   AIC                           3812.672
# Time:                        01:56:32   BIC                           3824.523
# Sample:                    02-05-2010   HQIC                          3817.487
#                          - 10-26-2012
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   5.246e+05   6.84e+04      7.671      0.000    3.91e+05    6.59e+05
# ar.L1          0.3673      0.048      7.660      0.000       0.273       0.461
# ar.L2          0.1227      0.075      1.637      0.102      -0.024       0.270
# ...

# %%
od=order.order
print("SARIMAX Order:",od)
# Out:
# SARIMAX Order: (2, 0, 0)

# %% [markdown]
# ## ARIMA Model

# %%
ar_model=ARIMA(df22["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
               enforce_stationarity=False)
ar_model=ar_model.fit()

forecast1=ar_model.forecast(steps=12)

# %%
forecast1
# Out:
# 2012-11-02    1.018191e+06
# 2012-11-09    1.050815e+06
# 2012-11-16    9.971783e+05
# 2012-11-23    1.464723e+06
# 2012-11-30    1.177348e+06
# 2012-12-07    1.292142e+06
# 2012-12-14    1.420228e+06
# 2012-12-21    1.773082e+06
# 2012-12-28    8.783608e+05
# 2013-01-04    9.067339e+05
# 2013-01-11    8.594138e+05
# 2013-01-18    8.970143e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df22.index,df22["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast1.index,forecast1, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# ## SARIMAX Model

# %%
model=SARIMAX(df22["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
              enforce_stationarity=False)
model=model.fit()
forecast2=model.forecast(steps=12)

# %%
forecast2
# Out:
# 2012-11-02    1.039625e+06
# 2012-11-09    1.080230e+06
# 2012-11-16    1.023169e+06
# 2012-11-23    1.389009e+06
# 2012-11-30    1.164886e+06
# 2012-12-07    1.258383e+06
# 2012-12-14    1.349003e+06
# 2012-12-21    1.617714e+06
# 2012-12-28    9.321146e+05
# 2013-01-04    9.640144e+05
# 2013-01-11    9.259388e+05
# 2013-01-18    9.552392e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df22["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast2.index,forecast2, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # Store 34

# %%
df=df34

# %%
df.head()
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05     956228.96             0        35.44       2.598  126.442065
# 2010-02-12     994610.99             1        36.13       2.573  126.496258
# 2010-02-19     983963.07             0        38.36       2.540  126.526286
# 2010-02-26     905756.13             0        37.28       2.590  126.552286
# 2010-03-05     918295.79             0        42.65       2.654  126.578286
#
#             Unemployment
# Date
# 2010-02-05         9.521
# 2010-02-12         9.521
# 2010-02-19         9.521
# 2010-02-26         9.521
# 2010-03-05         9.521

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2010-02-05 to 2012-10-26
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly_Sales  143 non-null    float64
#  1   Holiday_Flag  143 non-null    int64
#  2   Temperature   143 non-null    float64
#  3   Fuel_Price    143 non-null    float64
#  4   CPI           143 non-null    float64
#  5   Unemployment  143 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean   9.667816e+05      0.069930    58.495874    3.216972  128.679669
# std    1.046302e+05      0.255926    16.064125    0.416967    1.858300
# min    8.367178e+05      0.000000    23.820000    2.540000  126.064000
# 25%    9.202386e+05      0.000000    43.740000    2.764500  126.590094
# 50%    9.501542e+05      0.000000    59.290000    3.290000  129.075677
# 75%    9.795797e+05      0.000000    73.570000    3.586500  130.502414
# max    1.620748e+06      1.000000    81.960000    3.881000  131.193097
#
#        Unemployment
# count    143.000000
# mean       9.934804
# std        0.479994
# min        8.839000
# 25%        9.575000
# 50%        9.816000
# 75%       10.398000
# max       10.641000

# %%
# Line Plot of Weekly Sales over Time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Weekly_Sales'], marker='o', linestyle='-')
plt.title('Weekly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Histogram of Weekly Sales
plt.figure(figsize=(8, 5))
sns.histplot(df['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
average_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()

# Create a bar plot to compare average sales for holiday and non-holiday weeks
plt.figure(figsize=(8, 5))
sns.barplot(data=average_sales_by_holiday, x='Holiday_Flag', y='Weekly_Sales')
plt.title('Impact of Holidays on Weekly Sales')
plt.xlabel('Holiday Flag')
plt.ylabel('Average Weekly Sales')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.show()

# %%
# Create subplots for enhanced scatter plots
plt.figure(figsize=(16, 12))

# Enhanced scatter plot of Fuel Prices vs. CPI
plt.subplot(2, 3, 1)
sns.scatterplot(data=df10, x='CPI', y='Fuel_Price')
plt.title('Fuel_Prices vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Fuel_Prices')

# Enhanced scatter plot of Unemployment vs. CPI
plt.subplot(2, 3, 2)
sns.scatterplot(data=df10, x='Unemployment', y='CPI')
plt.title('Unemployment vs. CPI')
plt.xlabel('Unemployment')
plt.ylabel('CPI')

# Enhanced scatter plot of Temperature vs. Weekly Sales
plt.subplot(2, 3, 3)
sns.scatterplot(data=df10, x='Temperature', y='Weekly_Sales')
plt.title('Weekly Sales vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Fuel Price vs. Weekly Sales
plt.subplot(2, 3, 4)
sns.scatterplot(data=df10, x='Fuel_Price', y='Weekly_Sales')
plt.title('Weekly Sales vs. Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of CPI vs. Weekly Sales
plt.subplot(2, 3, 5)
sns.scatterplot(data=df10, x='CPI', y='Weekly_Sales')
plt.title('Weekly Sales vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Unemployment vs. Weekly Sales
plt.subplot(2, 3, 6)
sns.scatterplot(data=df10, x='Unemployment', y='Weekly_Sales')
plt.title('Weekly Sales vs. Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')

plt.tight_layout()
plt.show()

# %%
# Year-wise analysis
df['Year'] = df.index.year

# Create a line plot for each year
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Group the data by year and plot each year's weekly sales on the same graph
for year in df['Year'].unique():
    year_data = df[df['Year'] == year]
    sns.lineplot(data=year_data, x=year_data.index, y='Weekly_Sales', label=year)

plt.title('Year-Wise Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend(title='Year')
plt.show()

# Don't forget to remove the 'Year' column if it's not needed for further analysis
df.drop('Year', axis=1, inplace=True)

# %% [markdown]
# ## Check stationarity

# %%
# Define a function to perform the Dickey-Fuller test and display the results
def test_stationarity(timeseries):
    result = adfuller(timeseries, autolag='AIC')
    print("Dickey-Fuller Test Results:")
    print(f'Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags Used: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print(f'Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    
    # Determine if the series is stationary based on the p-value
    if result[1] <= 0.05:
        print("\nResult: The time series is stationary.")
    else:
        print("\nResult: The time series is not stationary.")

test_stationarity(df34['Weekly_Sales'])
# Out:
# Dickey-Fuller Test Results:
# Test Statistic: -4.76512241222132
# p-value: 6.338679701894124e-05
# Number of Lags Used: 4
# Number of Observations Used: 138
# Critical Values:
#    1%: -3.47864788917503
#    5%: -2.882721765644168
#    10%: -2.578065326612056
#
# Result: The time series is stationary.

# %%
plt.figure(figsize=(20, 8))
plt.plot(df34["Weekly_Sales"], label='Original Data', marker='o', linestyle='-')

# %%
decompose_result=seasonal_decompose(df34["Weekly_Sales"])
decompose_result.plot();

# %% [markdown]
# # Auto ARIMA

# %%
order=auto_arima(df34["Weekly_Sales"])
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  143
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -1847.639
# Date:                Wed, 08 Nov 2023   AIC                           3703.277
# Time:                        01:56:45   BIC                           3715.129
# Sample:                    02-05-2010   HQIC                          3708.093
#                          - 10-26-2012
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   5.974e+05   8.17e+04      7.308      0.000    4.37e+05    7.58e+05
# ar.L1          0.2618      0.053      4.913      0.000       0.157       0.366
# ar.L2          0.1202      0.090      1.341      0.180      -0.055       0.296
# ...

# %%
od=order.order
print("SARIMAX Order:",od)
# Out:
# SARIMAX Order: (2, 0, 0)

# %% [markdown]
# # ARIMA Model

# %%
ar_model=ARIMA(df34["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
               enforce_stationarity=False)
ar_model=ar_model.fit()

forecast1=ar_model.forecast(steps=12)

# %%
forecast1
# Out:
# 2012-11-02    9.771668e+05
# 2012-11-09    9.808112e+05
# 2012-11-16    9.594241e+05
# 2012-11-23    1.108452e+06
# 2012-11-30    9.704385e+05
# 2012-12-07    1.006701e+06
# 2012-12-14    1.009145e+06
# 2012-12-21    1.176518e+06
# 2012-12-28    9.843178e+05
# 2013-01-04    9.773672e+05
# 2013-01-11    9.526832e+05
# 2013-01-18    9.530370e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df34["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast1, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # SARIMAX Model

# %%
model=SARIMAX(df34["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
              enforce_stationarity=False)
model=model.fit()
forecast2=model.forecast(steps=12)

# %%
forecast2
# Out:
# 2012-11-02    1.050900e+06
# 2012-11-09    1.032300e+06
# 2012-11-16    9.890929e+05
# 2012-11-23    1.394010e+06
# 2012-11-30    1.042131e+06
# 2012-12-07    1.134902e+06
# 2012-12-14    1.242406e+06
# 2012-12-21    1.681804e+06
# 2012-12-28    9.795961e+05
# 2013-01-04    9.725893e+05
# 2013-01-11    9.492386e+05
# 2013-01-18    9.438454e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df34["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast2, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # Store 17

# %%
df = df17

# %%
df.head()
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05     789036.02             0        23.11       2.666  126.442065
# 2010-02-12     841951.91             1        18.36       2.671  126.496258
# 2010-02-19     800714.00             0        25.06       2.654  126.526286
# 2010-02-26     749549.55             0        15.64       2.667  126.552286
# 2010-03-05     783300.05             0        31.58       2.681  126.578286
#
#             Unemployment
# Date
# 2010-02-05         6.548
# 2010-02-12         6.548
# 2010-02-19         6.548
# 2010-02-26         6.548
# 2010-03-05         6.548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2010-02-05 to 2012-10-26
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly_Sales  143 non-null    float64
#  1   Holiday_Flag  143 non-null    int64
#  2   Temperature   143 non-null    float64
#  3   Fuel_Price    143 non-null    float64
#  4   CPI           143 non-null    float64
#  5   Unemployment  143 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean   8.935814e+05      0.069930    46.387203    3.286147  128.679669
# std    1.121629e+05      0.255926    17.213885    0.392727    1.858300
# min    6.358626e+05      0.000000     6.230000    2.654000  126.064000
# 25%    8.175188e+05      0.000000    31.830000    2.869000  126.590094
# 50%    8.728176e+05      0.000000    47.690000    3.380000  129.075677
# 75%    9.397343e+05      0.000000    60.750000    3.627000  130.502414
# max    1.309227e+06      1.000000    74.200000    3.845000  131.193097
#
#        Unemployment
# count    143.000000
# mean       6.549406
# std        0.325502
# min        5.527000
# 25%        6.403000
# 50%        6.635000
# 75%        6.774000
# max        6.885000

# %%
# Line Plot of Weekly Sales over Time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Weekly_Sales'], marker='o', linestyle='-')
plt.title('Weekly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Histogram of Weekly Sales
plt.figure(figsize=(8, 5))
sns.histplot(df['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
average_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()

# Create a bar plot to compare average sales for holiday and non-holiday weeks
plt.figure(figsize=(8, 5))
sns.barplot(data=average_sales_by_holiday, x='Holiday_Flag', y='Weekly_Sales')
plt.title('Impact of Holidays on Weekly Sales')
plt.xlabel('Holiday Flag')
plt.ylabel('Average Weekly Sales')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.show()

# %%
# Create subplots for enhanced scatter plots
plt.figure(figsize=(16, 12))

# Enhanced scatter plot of Fuel Prices vs. CPI
plt.subplot(2, 3, 1)
sns.scatterplot(data=df10, x='CPI', y='Fuel_Price')
plt.title('Fuel_Prices vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Fuel_Prices')

# Enhanced scatter plot of Unemployment vs. CPI
plt.subplot(2, 3, 2)
sns.scatterplot(data=df10, x='Unemployment', y='CPI')
plt.title('Unemployment vs. CPI')
plt.xlabel('Unemployment')
plt.ylabel('CPI')

# Enhanced scatter plot of Temperature vs. Weekly Sales
plt.subplot(2, 3, 3)
sns.scatterplot(data=df10, x='Temperature', y='Weekly_Sales')
plt.title('Weekly Sales vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Fuel Price vs. Weekly Sales
plt.subplot(2, 3, 4)
sns.scatterplot(data=df10, x='Fuel_Price', y='Weekly_Sales')
plt.title('Weekly Sales vs. Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of CPI vs. Weekly Sales
plt.subplot(2, 3, 5)
sns.scatterplot(data=df10, x='CPI', y='Weekly_Sales')
plt.title('Weekly Sales vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Unemployment vs. Weekly Sales
plt.subplot(2, 3, 6)
sns.scatterplot(data=df10, x='Unemployment', y='Weekly_Sales')
plt.title('Weekly Sales vs. Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')

plt.tight_layout()
plt.show()

# %%
df['Year'] = df.index.year

# Create a line plot for each year
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Group the data by year and plot each year's weekly sales on the same graph
for year in df['Year'].unique():
    year_data = df[df['Year'] == year]
    sns.lineplot(data=year_data, x=year_data.index, y='Weekly_Sales', label=year)

plt.title('Year-Wise Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend(title='Year')
plt.show()

# Don't forget to remove the 'Year' column if it's not needed for further analysis
df.drop('Year', axis=1, inplace=True)

# %% [markdown]
# ## Check stationarity

# %%
# Define a function to perform the Dickey-Fuller test and display the results
def test_stationarity(timeseries):
    result = adfuller(timeseries, autolag='AIC')
    print("Dickey-Fuller Test Results:")
    print(f'Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags Used: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print(f'Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    
    # Determine if the series is stationary based on the p-value
    if result[1] <= 0.05:
        print("\nResult: The time series is stationary.")
    else:
        print("\nResult: The time series is not stationary.")

test_stationarity(df17['Weekly_Sales'])
# Out:
# Dickey-Fuller Test Results:
# Test Statistic: -5.2923442719973375
# p-value: 5.679177242073061e-06
# Number of Lags Used: 1
# Number of Observations Used: 141
# Critical Values:
#    1%: -3.4776006742422374
#    5%: -2.882265832283648
#    10%: -2.5778219289774156
#
# Result: The time series is stationary.

# %%
plt.figure(figsize=(20, 8))
plt.plot(df17["Weekly_Sales"], label='Original Data', marker='o', linestyle='-')

# %%
decompose_result=seasonal_decompose(df17["Weekly_Sales"])
decompose_result.plot();

# %% [markdown]
# ## Auto ARIMA

# %%
order=auto_arima(df17["Weekly_Sales"])
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  143
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1856.401
# Date:                Wed, 08 Nov 2023   AIC                           3716.801
# Time:                        01:57:01   BIC                           3722.713
# Sample:                    02-05-2010   HQIC                          3719.204
#                          - 10-26-2012
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7406      0.040    -18.412      0.000      -0.819      -0.662
# sigma2      1.281e+10   5.99e-13   2.14e+22      0.000    1.28e+10    1.28e+10
# ...
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                83.41
# ...

# %%
od=order.order
print("SARIMAX Order:",od)
# Out:
# SARIMAX Order: (0, 1, 1)

# %% [markdown]
# # ARIMA Model

# %%
ar_model=ARIMA(df17["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
               enforce_stationarity=False)
ar_model=ar_model.fit()

forecast1=ar_model.forecast(steps=12)

# %%
forecast1
# Out:
# 2012-11-02    9.794961e+05
# 2012-11-09    9.682091e+05
# 2012-11-16    9.300566e+05
# 2012-11-23    1.273658e+06
# 2012-11-30    9.999820e+05
# 2012-12-07    1.031351e+06
# 2012-12-14    1.122342e+06
# 2012-12-21    1.344732e+06
# 2012-12-28    8.281754e+05
# 2013-01-04    1.249451e+06
# 2013-01-11    9.252764e+05
# 2013-01-18    8.630115e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df17["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast1, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # SARIMAX Model

# %%
model=SARIMAX(df17["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
              enforce_stationarity=False)
model=model.fit()
forecast2=model.forecast(steps=12)

# %%
forecast2
# Out:
# 2012-11-02    9.794961e+05
# 2012-11-09    9.682091e+05
# 2012-11-16    9.300566e+05
# 2012-11-23    1.273658e+06
# 2012-11-30    9.999820e+05
# 2012-12-07    1.031351e+06
# 2012-12-14    1.122342e+06
# 2012-12-21    1.344732e+06
# 2012-12-28    8.281754e+05
# 2013-01-04    1.249451e+06
# 2013-01-11    9.252764e+05
# 2013-01-18    8.630115e+05
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df17["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast2, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # Store 14

# %%
df=df14

# %%
df.head()
# Out:
#             Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Date
# 2010-02-05    2623469.95             0        27.31       2.784  181.871190
# 2010-02-12    1704218.84             1        27.73       2.773  181.982317
# 2010-02-19    2204556.70             0        31.27       2.745  182.034782
# 2010-02-26    2095591.63             0        34.89       2.754  182.077469
# 2010-03-05    2237544.75             0        37.13       2.777  182.120157
#
#             Unemployment
# Date
# 2010-02-05         8.992
# 2010-02-12         8.992
# 2010-02-19         8.992
# 2010-02-26         8.992
# 2010-03-05         8.992

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2010-02-05 to 2012-10-26
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly_Sales  143 non-null    float64
#  1   Holiday_Flag  143 non-null    int64
#  2   Temperature   143 non-null    float64
#  3   Fuel_Price    143 non-null    float64
#  4   CPI           143 non-null    float64
#  5   Unemployment  143 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean   2.020978e+06      0.069930    57.790979    3.417608  186.285678
# std    3.175699e+05      0.255926    16.271612    0.443029    3.594820
# min    1.479515e+06      0.000000    24.050000    2.699000  181.646815
# 25%    1.873298e+06      0.000000    45.585000    2.921000  182.619515
# 50%    2.004330e+06      0.000000    58.850000    3.541000  185.937438
# 75%    2.125780e+06      0.000000    72.585000    3.809000  189.924736
# max    3.818686e+06      1.000000    82.990000    4.066000  192.330854
#
#        Unemployment
# count    143.000000
# mean       8.648748
# std        0.151460
# min        8.424000
# 25%        8.523000
# 50%        8.625000
# 75%        8.724000
# max        8.992000

# %%
# Line Plot of Weekly Sales over Time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Weekly_Sales'], marker='o', linestyle='-')
plt.title('Weekly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
# Histogram of Weekly Sales
plt.figure(figsize=(8, 5))
sns.histplot(df['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
average_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()

# Create a bar plot to compare average sales for holiday and non-holiday weeks
plt.figure(figsize=(8, 5))
sns.barplot(data=average_sales_by_holiday, x='Holiday_Flag', y='Weekly_Sales')
plt.title('Impact of Holidays on Weekly Sales')
plt.xlabel('Holiday Flag')
plt.ylabel('Average Weekly Sales')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.show()

# %%
# Create subplots for enhanced scatter plots
plt.figure(figsize=(16, 12))

# Enhanced scatter plot of Fuel Prices vs. CPI
plt.subplot(2, 3, 1)
sns.scatterplot(data=df10, x='CPI', y='Fuel_Price')
plt.title('Fuel_Prices vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Fuel_Prices')

# Enhanced scatter plot of Unemployment vs. CPI
plt.subplot(2, 3, 2)
sns.scatterplot(data=df10, x='Unemployment', y='CPI')
plt.title('Unemployment vs. CPI')
plt.xlabel('Unemployment')
plt.ylabel('CPI')

# Enhanced scatter plot of Temperature vs. Weekly Sales
plt.subplot(2, 3, 3)
sns.scatterplot(data=df10, x='Temperature', y='Weekly_Sales')
plt.title('Weekly Sales vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Fuel Price vs. Weekly Sales
plt.subplot(2, 3, 4)
sns.scatterplot(data=df10, x='Fuel_Price', y='Weekly_Sales')
plt.title('Weekly Sales vs. Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of CPI vs. Weekly Sales
plt.subplot(2, 3, 5)
sns.scatterplot(data=df10, x='CPI', y='Weekly_Sales')
plt.title('Weekly Sales vs. CPI')
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')

# Enhanced scatter plot of Unemployment vs. Weekly Sales
plt.subplot(2, 3, 6)
sns.scatterplot(data=df10, x='Unemployment', y='Weekly_Sales')
plt.title('Weekly Sales vs. Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')

plt.tight_layout()
plt.show()

# %%
# Year-wise analysis
df['Year'] = df.index.year

# Create a line plot for each year
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Group the data by year and plot each year's weekly sales on the same graph
for year in df['Year'].unique():
    year_data = df[df['Year'] == year]
    sns.lineplot(data=year_data, x=year_data.index, y='Weekly_Sales', label=year)

plt.title('Year-Wise Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend(title='Year')
plt.show()

# Don't forget to remove the 'Year' column if it's not needed for further analysis
df.drop('Year', axis=1, inplace=True)

# %% [markdown]
# ## Checking stationarity

# %%
# Define a function to perform the Dickey-Fuller test and display the results
def test_stationarity(timeseries):
    result = adfuller(timeseries, autolag='AIC')
    print("Dickey-Fuller Test Results:")
    print(f'Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags Used: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print(f'Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    
    # Determine if the series is stationary based on the p-value
    if result[1] <= 0.05:
        print("\nResult: The time series is stationary.")
    else:
        print("\nResult: The time series is not stationary.")

test_stationarity(df14['Weekly_Sales'])
# Out:
# Dickey-Fuller Test Results:
# Test Statistic: -2.7368866106751986
# p-value: 0.06786986708375117
# Number of Lags Used: 6
# Number of Observations Used: 136
# Critical Values:
#    1%: -3.4793722137854926
#    5%: -2.8830370378332995
#    10%: -2.578233635380623
#
# Result: The time series is not stationary.

# %%
plt.figure(figsize=(20, 8))
plt.plot(df14["Weekly_Sales"], label='Original Data', marker='o', linestyle='-')

# %%
decompose_result=seasonal_decompose(df14["Weekly_Sales"])
decompose_result.plot();

# %% [markdown]
# # Auto ARIMA

# %%
order=auto_arima(df14["Weekly_Sales"])
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  143
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -1978.589
# Date:                Wed, 08 Nov 2023   AIC                           3967.178
# Time:                        01:57:14   BIC                           3981.958
# Sample:                    02-05-2010   HQIC                          3973.184
#                          - 10-26-2012
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1856      0.212     -0.876      0.381      -0.601       0.230
# ar.L2          0.4308      0.115      3.734      0.000       0.205       0.657
# ma.L1         -0.3766      0.221     -1.705      0.088      -0.810       0.056
# ...

# %%
od=order.order
print("SARIMAX Order:",od)
# Out:
# SARIMAX Order: (2, 1, 2)

# %% [markdown]
# # ARIMA Model

# %%
ar_model=ARIMA(df14["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
               enforce_stationarity=False)
ar_model=ar_model.fit()

forecast1=ar_model.forecast(steps=12)

# %%
forecast1
# Out:
# 2012-11-02    1.829872e+06
# 2012-11-09    1.743578e+06
# 2012-11-16    1.628940e+06
# 2012-11-23    2.346166e+06
# 2012-11-30    1.803294e+06
# 2012-12-07    2.131088e+06
# 2012-12-14    2.254727e+06
# 2012-12-21    3.029502e+06
# 2012-12-28    1.574548e+06
# 2013-01-04    1.519561e+06
# 2013-01-11    1.356656e+06
# 2013-01-18    1.449525e+06
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df14["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast1, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()

# %% [markdown]
# # SARIMAX Model

# %%
model=SARIMAX(df14["Weekly_Sales"],order=od,seasonal_order=od + (52,),enforce_invertibility=False,
              enforce_stationarity=False)
model=model.fit()
forecast2=model.forecast(steps=12)

# %%
forecast2
# Out:
# 2012-11-02    1.829872e+06
# 2012-11-09    1.743578e+06
# 2012-11-16    1.628940e+06
# 2012-11-23    2.346166e+06
# 2012-11-30    1.803294e+06
# 2012-12-07    2.131088e+06
# 2012-12-14    2.254727e+06
# 2012-12-21    3.029502e+06
# 2012-12-28    1.574548e+06
# 2013-01-04    1.519561e+06
# 2013-01-11    1.356656e+06
# 2013-01-18    1.449525e+06
# Freq: W-FRI, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df14["Weekly_Sales"], label='Original', color='blue', marker='o', linestyle='-')

# Plot the forecasted values
plt.plot(forecast2, label='Forecast', color='red', marker='o', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('Original Time Series vs. Forecast')
plt.legend()
